# %% [markdown]
# ## Teste de performance dos Algoritmos de SSSP

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from matplotlib import pyplot as plt

# %% [markdown]
# #### 1. Configurando parâmetros para rotina de testes

# %%
from random import seed
from graphs.graphs import dijkstra, generate_random_graph
from graphs.duan_et_al import sssp_duan_et_al
import csv

# Garantir reprodutibilidade
seed(42)

# Quantidade de grafos por configuração
num_graphs = 5

# Quantidade de vértices
num_vertices = (100, 1000, 10000)

# Grau médio
grau_médio = (1.5, 4, 10) 

# Algoritmos
algorithms = (dijkstra, sssp_duan_et_al)

# %% [markdown]
# #### 2. Executando rotina de testes

# %%
from time import perf_counter
import csv

results = []

qt_executions = (
    len(num_vertices)
    * len(grau_médio)
    * len(algorithms)
    * num_graphs
)

current_execution = 0

for num_v in num_vertices:
    for k in grau_médio:

        # conversão para probabilidade equivalente no G(n, p)
        edge_prob = k / (num_v - 1)

        # estimativa realista de número de arestas
        edge_estimate = (num_v * k)

        for alg in algorithms:
            for _ in range(num_graphs):

                g = generate_random_graph(num_v, edge_prob)

                current_execution += 1
                progress = (current_execution / qt_executions) * 100

                print(
                    f"Executed {progress:.2f}% "
                    f"| num_vertices: {num_v} "
                    f"| k(avg_degree): {k:.2f} "
                    f"| algorithm: {alg.__name__} "
                    f"| edge_estimate: {edge_estimate:.0f}",
                    flush=True
                )

                start_time = perf_counter()
                r = alg(g, 0)
                end_time = perf_counter()

                delta_time = end_time - start_time

                results.append({
                    "num_vertices": num_v,
                    "avg_degree_k": k,
                    "algorithm": alg.__name__,
                    "execution_time": delta_time,
                    "edge_estimate": edge_estimate
                })

print("\nExecution finished.")

# Salvar os resultados em CSV
with open('data/first_results.csv', 'w', newline='') as f:
    writer = csv.DictWriter(
        f,
        fieldnames=[
            "num_vertices",
            "avg_degree_k",
            "algorithm",
            "execution_time",
            "edge_estimate"
        ]
    )

    writer.writeheader()
    writer.writerows(results)
# Out:
# Executed 1.11% | num_vertices: 100 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 150
# Executed 2.22% | num_vertices: 100 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 150
# Executed 3.33% | num_vertices: 100 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 150
# Executed 4.44% | num_vertices: 100 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 150
# Executed 5.56% | num_vertices: 100 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 150
# Executed 6.67% | num_vertices: 100 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 150
# Executed 7.78% | num_vertices: 100 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 150
# Executed 8.89% | num_vertices: 100 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 150
# Executed 10.00% | num_vertices: 100 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 150
# Executed 11.11% | num_vertices: 100 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 150
# Executed 12.22% | num_vertices: 100 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 400
# Executed 13.33% | num_vertices: 100 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 400
# Executed 14.44% | num_vertices: 100 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 400
# Executed 15.56% | num_vertices: 100 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 400
# Executed 16.67% | num_vertices: 100 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 400
# Executed 17.78% | num_vertices: 100 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 400
# Executed 18.89% | num_vertices: 100 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 400
# Executed 20.00% | num_vertices: 100 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 400
# Executed 21.11% | num_vertices: 100 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 400
# Executed 22.22% | num_vertices: 100 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 400
# Executed 23.33% | num_vertices: 100 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 1000
# Executed 24.44% | num_vertices: 100 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 1000
# Executed 25.56% | num_vertices: 100 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 1000
# Executed 26.67% | num_vertices: 100 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 1000
# Executed 27.78% | num_vertices: 100 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 1000
# Executed 28.89% | num_vertices: 100 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 1000
# Executed 30.00% | num_vertices: 100 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 1000
# Executed 31.11% | num_vertices: 100 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 1000
# Executed 32.22% | num_vertices: 100 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 1000
# Executed 33.33% | num_vertices: 100 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 1000
# Executed 34.44% | num_vertices: 1000 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 1500
# Executed 35.56% | num_vertices: 1000 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 1500
# Executed 36.67% | num_vertices: 1000 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 1500
# Executed 37.78% | num_vertices: 1000 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 1500
# Executed 38.89% | num_vertices: 1000 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 1500
# Executed 40.00% | num_vertices: 1000 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 1500
# Executed 41.11% | num_vertices: 1000 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 1500
# Executed 42.22% | num_vertices: 1000 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 1500
# Executed 43.33% | num_vertices: 1000 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 1500
# Executed 44.44% | num_vertices: 1000 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 1500
# Executed 45.56% | num_vertices: 1000 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 4000
# Executed 46.67% | num_vertices: 1000 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 4000
# Executed 47.78% | num_vertices: 1000 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 4000
# Executed 48.89% | num_vertices: 1000 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 4000
# Executed 50.00% | num_vertices: 1000 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 4000
# Executed 51.11% | num_vertices: 1000 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 4000
# Executed 52.22% | num_vertices: 1000 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 4000
# Executed 53.33% | num_vertices: 1000 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 4000
# Executed 54.44% | num_vertices: 1000 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 4000
# Executed 55.56% | num_vertices: 1000 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 4000
# Executed 56.67% | num_vertices: 1000 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 10000
# Executed 57.78% | num_vertices: 1000 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 10000
# Executed 58.89% | num_vertices: 1000 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 10000
# Executed 60.00% | num_vertices: 1000 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 10000
# Executed 61.11% | num_vertices: 1000 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 10000
# Executed 62.22% | num_vertices: 1000 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 10000
# Executed 63.33% | num_vertices: 1000 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 10000
# Executed 64.44% | num_vertices: 1000 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 10000
# Executed 65.56% | num_vertices: 1000 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 10000
# Executed 66.67% | num_vertices: 1000 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 10000
# Executed 67.78% | num_vertices: 10000 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 15000
# Executed 68.89% | num_vertices: 10000 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 15000
# Executed 70.00% | num_vertices: 10000 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 15000
# Executed 71.11% | num_vertices: 10000 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 15000
# Executed 72.22% | num_vertices: 10000 | k(avg_degree): 1.50 | algorithm: dijkstra | edge_estimate: 15000
# Executed 73.33% | num_vertices: 10000 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 15000
# Executed 74.44% | num_vertices: 10000 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 15000
# Executed 75.56% | num_vertices: 10000 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 15000
# Executed 76.67% | num_vertices: 10000 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 15000
# Executed 77.78% | num_vertices: 10000 | k(avg_degree): 1.50 | algorithm: sssp_duan_et_al | edge_estimate: 15000
# Executed 78.89% | num_vertices: 10000 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 40000
# Executed 80.00% | num_vertices: 10000 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 40000
# Executed 81.11% | num_vertices: 10000 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 40000
# Executed 82.22% | num_vertices: 10000 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 40000
# Executed 83.33% | num_vertices: 10000 | k(avg_degree): 4.00 | algorithm: dijkstra | edge_estimate: 40000
# Executed 84.44% | num_vertices: 10000 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 40000
# Executed 85.56% | num_vertices: 10000 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 40000
# Executed 86.67% | num_vertices: 10000 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 40000
# Executed 87.78% | num_vertices: 10000 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 40000
# Executed 88.89% | num_vertices: 10000 | k(avg_degree): 4.00 | algorithm: sssp_duan_et_al | edge_estimate: 40000
# Executed 90.00% | num_vertices: 10000 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 100000
# Executed 91.11% | num_vertices: 10000 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 100000
# Executed 92.22% | num_vertices: 10000 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 100000
# Executed 93.33% | num_vertices: 10000 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 100000
# Executed 94.44% | num_vertices: 10000 | k(avg_degree): 10.00 | algorithm: dijkstra | edge_estimate: 100000
# Executed 95.56% | num_vertices: 10000 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 100000
# Executed 96.67% | num_vertices: 10000 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 100000
# Executed 97.78% | num_vertices: 10000 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 100000
# Executed 98.89% | num_vertices: 10000 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 100000
# Executed 100.00% | num_vertices: 10000 | k(avg_degree): 10.00 | algorithm: sssp_duan_et_al | edge_estimate: 100000
#
# Execution finished.
